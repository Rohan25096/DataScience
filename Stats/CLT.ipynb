# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
num_samples = 1000
sample_size = 30
distribution_range = (0,1)

sample = np.random.uniform(distribution_range[0],distribution_range[1], (num_samples, sample_size))
samples = np.round(samples, 2)

# %%
samples
# Out:
# array([[0.88, 0.52, 0.08, ..., 0.24, 0.87, 0.7 ],
#        [0.09, 0.79, 0.15, ..., 0.5 , 0.39, 0.9 ],
#        [0.91, 0.38, 0.95, ..., 0.87, 0.53, 0.12],
#        ...,
#        [0.2 , 0.1 , 0.57, ..., 0.37, 0.48, 0.6 ],
#        [0.  , 0.91, 0.6 , ..., 0.65, 0.14, 0.33],
#        [0.81, 0.71, 0.6 , ..., 0.89, 0.28, 0.85]])

# %%
sample_mean = np.mean(samples, axis=1)

# %%
plt.hist(sample_mean, bins=30, density=True, edgecolor='black')
plt.title('Hsitogram of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()
