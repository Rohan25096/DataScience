# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleanned.csv')
df
# Out:
#      age     sex              cp  trestbps   chol    fbs           restecg  \
# 0     63    Male  typical angina     145.0  233.0   True    lv hypertrophy
# 1     67    Male    asymptomatic     160.0  286.0  False    lv hypertrophy
# 2     67    Male    asymptomatic     120.0  229.0  False    lv hypertrophy
# 3     37    Male     non-anginal     130.0  250.0  False            normal
# 4     41  Female  typical angina     130.0  204.0  False    lv hypertrophy
# ..   ...     ...             ...       ...    ...    ...               ...
# 913   54  Female    asymptomatic     127.0  333.0   True  st-t abnormality
# 914   62    Male  typical angina     130.0  139.0  False  st-t abnormality
# 915   55    Male    asymptomatic     122.0  223.0   True  st-t abnormality
# 916   58    Male    asymptomatic     130.0  385.0   True    lv hypertrophy
# 917   62    Male  typical angina     120.0  254.0  False    lv hypertrophy
#
#      thalch  exang  oldpeak  num
# 0     150.0  False      2.3    0
# ...
