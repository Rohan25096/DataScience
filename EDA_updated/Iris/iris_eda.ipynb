# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
! pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 2.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 1.8 MB/s eta 0:00:00
# ...

# %%
iris_df = pd.read_csv('iris.csv')

# %%
iris_df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Sepal Length
# ### Conclusions:
# - There are no outlier detected in the column and the median of the column is somewhere between the range (5.5 to 6).
# - Next, we find median of sepal length between the all 3 species(setosa, versicolor and virginica) respectively as 5.0, 5.85, 6.0

# %%
iris_df['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
sns.boxplot(data = iris_df, x='sepal_length')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
sns.kdeplot(data = iris_df, x='sepal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.boxplot(data = iris_df, x='sepal_length',hue='species')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
iris_df['sepal_length'].isnull().sum()
# Out:
# np.int64(0)

# %%
iris_df['sepal_length'].skew()
# Out:
# np.float64(0.3149109566369728)

# %% [markdown]
# # Sepal Width
# ### Conclusions:
# - The column sepal width has a median of 3.05
# - We find the median of sepal widthbetween all the 3 species(setosa, versicolor and verginica) respectively as 3.4, 2.75, 3.0

# %%
iris_df['sepal_width'].describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64

# %%
sns.boxplot(data = iris_df, x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
sns.kdeplot(data = iris_df, x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.boxplot(data = iris_df, x='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
iris_df['sepal_width'].isnull().sum()
# Out:
# np.int64(0)

# %%
iris_df['sepal_width'].skew()
# Out:
# np.float64(0.31896566471359966)

# %% [markdown]
# # Petal Length
# ### Conclusions:
# - The median of petal length is somewhere around 4.2
# - The petal length of all the 3 different species differ alot, by the data we can conclude that the median of setosa is somewhere around 1.6, but the median of versicolor and virginica are somewhere around 4.3 and 5.6 respectively.
# - By this we can say that features of versicolor and verginica match alot.
# - The probability of finding any petal length between 2 to 4 is the least.

# %%
iris_df['petal_length'].describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
sns.boxplot(data = iris_df, x='petal_length')
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.boxplot(data = iris_df, x='petal_length', hue='species')
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.kdeplot(data = iris_df, x='petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(data = iris_df, x='petal_length', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
iris_df['petal_length'].isnull().sum()
# Out:
# np.int64(0)

# %%
iris_df['petal_length'].skew()
# Out:
# np.float64(-0.27488417975101276)

# %% [markdown]
# # Petal Width
# ### Conclusions:
# - The median of setosa lies between (0-0.5)
# - While, the median of Versicolor and Virginica respectively are (1.0-1.5) and (1.5-2.0)
# - We can se that Setosa's petal width is quite concentrated in a single region while that of Versicolor and Virginica they are scattered through out.

# %%
iris_df['petal_width'].describe()
# Out:
# count    150.000000
# mean       1.199333
# std        0.762238
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_width, dtype: float64

# %%
sns.boxplot(data = iris_df, x='petal_width')
# Out:
# <Axes: xlabel='petal_width'>

# %%
sns.boxplot(data = iris_df, x='petal_width', hue='species')
# Out:
# <Axes: xlabel='petal_width'>

# %%
sns.kdeplot(data = iris_df, x='petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(data = iris_df, x='petal_width', hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
iris_df['petal_width'].isnull().sum()
# Out:
# np.int64(0)

# %%
iris_df['petal_width'].skew()
# Out:
# np.float64(-0.10296674764898116)

# %% [markdown]
# # Species
# ### Conclusions:
# - There are 3 diffrent species of each count 50.

# %%
iris_df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
iris_df.groupby('species').median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
px.scatter(iris_df,x='sepal_length',y='petal_length',color='species')

# %%
px.scatter(iris_df,x='petal_length',y='petal_width',color='species')

# %% [markdown]
# # Multivariate Analysis

# %%
px.scatter_3d(iris_df,x='petal_length', y='petal_width', z='sepal_length', color='species')

# %%
sns.pairplot(iris_df, hue='species')

# %%
px.scatter_matrix(iris_df, dimensions=['sepal_length','sepal_width','petal_length','petal_width'], color='species')

# %%
analyze_reports = sw.analyze(iris_df)
analyze_report.show_html('analyze.html',open_browser=False)

# %%
import IPython
IPython.display.HTML('analyze.html')
# Out:
# analyze.html

# %%
! pip install numpy==1.19.5
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.3 MB 155.4 kB/s eta 0:01:23
# ...

# %%
! pip install --upgrade sweetviz
